# %%
import pandas as pd
import mysql.connector

# %%
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\python.exe -m pip install --upgrade pip' command.

# %%
conn = mysql.connector.connect(host="localhost",
                              user = "root",
                              password = "W7301@jqir#",
                              database = "fixmessages")

# %%
query = "select * from fixmessages.record "

# %%
df = pd.read_sql(query,conn)
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2848\354633662.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)
#    msg_type  msg_seq_num sender_comp_id target_comp_id        sending_time  \
# 0         0            1    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:00:00
# 1         0            1    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:00:00
# 2         0            1    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:00:00
# 3         0            1    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:00:00
# 4         1            2    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:01:00
# ..      ...          ...            ...            ...                 ...
# 94        T           27    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:25:00
# 95        U           28    JOHN_SENDER    MIKE_TARGET 2024-08-26 10:26:00
# ...
